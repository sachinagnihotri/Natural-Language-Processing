# %% [markdown]
# <a href="https://colab.research.google.com/github/sachinagnihotri/Natural-Language-Processing/blob/main/E1ML_sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

# Download required NLTK resources
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('tagsets')  # optional, for reference
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package tagsets to /root/nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# True

# %%
import numpy as np
import re
import time
import nltk
import optuna
from tensorflow.keras.datasets import imdb
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import FunctionTransformer
import warnings
warnings.filterwarnings("ignore")

# %%
# Load IMDB dataset
num_words = 30000
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=num_words)
x = np.concatenate((x_train, x_test), axis=0)
y = np.concatenate((y_train, y_test), axis=0)

# Decode integer sequences
word_index = imdb.get_word_index()
reverse_word_index = {value + 3: key for key, value in word_index.items()}
reverse_word_index[0] = "<PAD>"
reverse_word_index[1] = "<START>"
reverse_word_index[2] = "<UNK>"
reverse_word_index[3] = "<UNUSED>"

def decode_review(sequence):
    return ' '.join([reverse_word_index.get(i, '?') for i in sequence])

x_text = [decode_review(seq) for seq in x]

# Text cleaning
def clean_text(text):
    text = text.lower()
    text = re.sub(r"<.*?>", " ", text)
    text = re.sub(r"http\S+|www\S+", " ", text)
    text = re.sub(r"[^a-z\s]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

x_clean = [clean_text(t) for t in x_text]

# Split 80/20
x_train_text, x_test_text, y_train, y_test = train_test_split(
    x_clean, y, test_size=0.2, random_state=42, stratify=y
)

# POS tagging transformer
class POSTagger(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        pos_texts = []
        for doc in X:
            tokens = nltk.word_tokenize(doc)
            pos_tags = [tag for word, tag in nltk.pos_tag(tokens)]
            pos_texts.append(" ".join(pos_tags))
        return pos_texts

# %%
# Combine word TF-IDF and POS TF-IDF
word_vectorizer = TfidfVectorizer(max_features=30000, ngram_range=(1, 2), stop_words='english', sublinear_tf=True)
pos_vectorizer = TfidfVectorizer(max_features=5000, ngram_range=(1, 2), sublinear_tf=True)

feature_union = FeatureUnion([
    ('word_tfidf', word_vectorizer),
    ('pos_tfidf', Pipeline([
        ('pos', POSTagger()),
        ('tfidf', pos_vectorizer)
    ]))
])

x_train_tfidf = feature_union.fit_transform(x_train_text)
x_test_tfidf = feature_union.transform(x_test_text)

print("TF-IDF + POS training shape:", x_train_tfidf.shape)
print("TF-IDF + POS test shape:", x_test_tfidf.shape)
# Out:
# TF-IDF + POS training shape: (40000, 30905)
# TF-IDF + POS test shape: (10000, 30905)

# %%
import optuna
import time
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

results = []

# Helper function to run Optuna study for a given model
def run_optuna(name, objective_fn, n_trials=20):
    print(f"\nOptimizing {name} with Optuna...")
    start_time = time.time()

    study = optuna.create_study(direction="maximize")
    study.optimize(objective_fn, n_trials=n_trials)

    best_params = study.best_params
    best_model = objective_fn(trial=None, return_model=True, best_params=best_params)

    train_acc = accuracy_score(y_train, best_model.predict(x_train_tfidf))
    test_acc = accuracy_score(y_test, best_model.predict(x_test_tfidf))
    runtime = time.time() - start_time

    print(f"Best params: {best_params}")
    print(f"Train acc: {train_acc:.4f}, Test acc: {test_acc:.4f}, Time: {runtime:.2f}s")

    results.append({
        "Model": name,
        "Best Params": best_params,
        "Train Acc": train_acc,
        "Test Acc": test_acc,
        "Runtime (s)": runtime
    })

# %%
def lr_objective(trial, return_model=False, best_params=None):
    if best_params is None:
        C = trial.suggest_loguniform("C", 0.01, 10)
        solver = trial.suggest_categorical("solver", ["lbfgs", "liblinear"])
    else:
        C = best_params["C"]
        solver = best_params["solver"]

    model = LogisticRegression(C=C, solver=solver, max_iter=5000)
    if return_model:
        model.fit(x_train_tfidf, y_train)
        return model
    score = cross_val_score(model, x_train_tfidf, y_train, cv=3, scoring="accuracy", n_jobs=-1).mean()
    return score

run_optuna("Logistic Regression", lr_objective, n_trials=30)
# Out:
# [I 2025-11-10 16:56:59,323] A new study created in memory with name: no-name-81cec304-400a-4b85-8367-0041b414cdc4
# Optimizing Logistic Regression with Optuna...
# [I 2025-11-10 16:57:01,917] Trial 0 finished with value: 0.7997250328738345 and parameters: {'C': 0.017100277399992744, 'solver': 'lbfgs'}. Best is trial 0 with value: 0.7997250328738345.
# [I 2025-11-10 16:57:05,776] Trial 1 finished with value: 0.8784000404719882 and parameters: {'C': 0.33940562784296335, 'solver': 'liblinear'}. Best is trial 1 with value: 0.8784000404719882.
# [I 2025-11-10 16:57:06,574] Trial 2 finished with value: 0.7867500572320067 and parameters: {'C': 0.010820202511856801, 'solver': 'lbfgs'}. Best is trial 1 with value: 0.8784000404719882.
# [I 2025-11-10 16:57:11,765] Trial 3 finished with value: 0.8951000717420815 and parameters: {'C': 1.469035083307254, 'solver': 'liblinear'}. Best is trial 3 with value: 0.8951000717420815.
# [I 2025-11-10 16:57:13,481] Trial 4 finished with value: 0.7979250553710221 and parameters: {'C': 0.015873569370860156, 'solver': 'liblinear'}. Best is trial 3 with value: 0.8951000717420815.
# [I 2025-11-10 16:57:17,631] Trial 5 finished with value: 0.8599500385739732 and parameters: {'C': 0.132661642870412, 'solver': 'liblinear'}. Best is trial 3 with value: 0.8951000717420815.
# [I 2025-11-10 16:57:19,720] Trial 6 finished with value: 0.8686000542093949 and parameters: {'C': 0.19108739332384117, 'solver': 'lbfgs'}. Best is trial 3 with value: 0.8951000717420815.
# [I 2025-11-10 16:57:22,746] Trial 7 finished with value: 0.807450057257881 and parameters: {'C': 0.022215163304695862, 'solver': 'liblinear'}. Best is trial 3 with value: 0.8951000717420815.
# [I 2025-11-10 16:57:25,168] Trial 8 finished with value: 0.893725078615191 and parameters: {'C': 1.186654151714119, 'solver': 'lbfgs'}. Best is trial 3 with value: 0.8951000717420815.
# [I 2025-11-10 16:57:26,144] Trial 9 finished with value: 0.8425500066780206 and parameters: {'C': 0.06899466608950762, 'solver': 'lbfgs'}. Best is trial 3 with value: 0.8951000717420815.
# [I 2025-11-10 16:57:34,577] Trial 10 finished with value: 0.8969250254955189 and parameters: {'C': 6.0158812896427944, 'solver': 'liblinear'}. Best is trial 10 with value: 0.8969250254955189.
# [I 2025-11-10 16:57:43,505] Trial 11 finished with value: 0.8964750386196284 and parameters: {'C': 9.035498343435204, 'solver': 'liblinear'}. Best is trial 10 with value: 0.8969250254955189.
# [I 2025-11-10 16:57:51,963] Trial 12 finished with value: 0.8963000379944251 and parameters: {'C': 9.30814918760374, 'solver': 'liblinear'}. Best is trial 10 with value: 0.8969250254955189.
# [I 2025-11-10 16:58:01,092] Trial 13 finished with value: 0.8963000379944251 and parameters: {'C': 9.291137764955048, 'solver': 'liblinear'}. Best is trial 10 with value: 0.8969250254955189.
# [I 2025-11-10 16:58:07,322] Trial 14 finished with value: 0.8969000417450813 and parameters: {'C': 3.1302535024622054, 'solver': 'liblinear'}. Best is trial 10 with value: 0.8969250254955189.
# [I 2025-11-10 16:58:13,489] Trial 15 finished with value: 0.896750028620222 and parameters: {'C': 2.5223104805430174, 'solver': 'liblinear'}. Best is trial 10 with value: 0.8969250254955189.
# [I 2025-11-10 16:58:19,380] Trial 16 finished with value: 0.8968500367451439 and parameters: {'C': 2.7802781852304497, 'solver': 'liblinear'}. Best is trial 10 with value: 0.8969250254955189.
# [I 2025-11-10 16:58:24,422] Trial 17 finished with value: 0.8888000848588785 and parameters: {'C': 0.6715705178186917, 'solver': 'liblinear'}. Best is trial 10 with value: 0.8969250254955189.
# [I 2025-11-10 16:58:30,483] Trial 18 finished with value: 0.8971250398704095 and parameters: {'C': 3.6069711568026546, 'solver': 'liblinear'}. Best is trial 18 with value: 0.8971250398704095.
# [I 2025-11-10 16:58:38,095] Trial 19 finished with value: 0.8975500317461439 and parameters: {'C': 4.074264683468836, 'solver': 'liblinear'}. Best is trial 19 with value: 0.8975500317461439.
# [I 2025-11-10 16:58:42,714] Trial 20 finished with value: 0.8876000848573787 and parameters: {'C': 0.6290779310107619, 'solver': 'liblinear'}. Best is trial 19 with value: 0.8975500317461439.
# [I 2025-11-10 16:58:50,888] Trial 21 finished with value: 0.8975500261212845 and parameters: {'C': 4.551782686798209, 'solver': 'liblinear'}. Best is trial 19 with value: 0.8975500317461439.
# [I 2025-11-10 16:58:58,463] Trial 22 finished with value: 0.8976000236214094 and parameters: {'C': 4.510838215623556, 'solver': 'liblinear'}. Best is trial 22 with value: 0.8976000236214094.
# [I 2025-11-10 16:59:04,249] Trial 23 finished with value: 0.8947500761165346 and parameters: {'C': 1.367142013090141, 'solver': 'liblinear'}. Best is trial 22 with value: 0.8976000236214094.
# [I 2025-11-10 16:59:12,493] Trial 24 finished with value: 0.8969750398702221 and parameters: {'C': 3.7611174837692314, 'solver': 'liblinear'}. Best is trial 22 with value: 0.8976000236214094.
# [I 2025-11-10 16:59:20,746] Trial 25 finished with value: 0.8975250329960813 and parameters: {'C': 4.984440949593854, 'solver': 'liblinear'}. Best is trial 22 with value: 0.8976000236214094.
# [I 2025-11-10 16:59:22,503] Trial 26 finished with value: 0.895250071742269 and parameters: {'C': 1.654552392808075, 'solver': 'lbfgs'}. Best is trial 22 with value: 0.8976000236214094.
# [I 2025-11-10 16:59:26,793] Trial 27 finished with value: 0.8868000798565037 and parameters: {'C': 0.5921158969301716, 'solver': 'liblinear'}. Best is trial 22 with value: 0.8976000236214094.
# [I 2025-11-10 16:59:34,533] Trial 28 finished with value: 0.897300027370941 and parameters: {'C': 5.5818723554383, 'solver': 'liblinear'}. Best is trial 22 with value: 0.8976000236214094.
# [I 2025-11-10 16:59:36,175] Trial 29 finished with value: 0.8963500392444564 and parameters: {'C': 2.1003152309568613, 'solver': 'lbfgs'}. Best is trial 22 with value: 0.8976000236214094.
# Best params: {'C': 4.510838215623556, 'solver': 'liblinear'}
# Train acc: 0.9753, Test acc: 0.8994, Time: 163.37s

# %%
def svm_objective(trial, return_model=False, best_params=None):
    if best_params is None:
        C = trial.suggest_loguniform("C", 0.01, 10)
    else:
        C = best_params["C"]

    model = LinearSVC(C=C, max_iter=10000)
    if return_model:
        model.fit(x_train_tfidf, y_train)
        return model
    score = cross_val_score(model, x_train_tfidf, y_train, cv=3, scoring="accuracy", n_jobs=-1).mean()
    return score

run_optuna("Linear SVM", svm_objective, n_trials=30)
# Out:
# [I 2025-11-10 16:59:42,702] A new study created in memory with name: no-name-a31e7bbd-b8b4-48e3-b065-55b1d39f3559
# Optimizing Linear SVM with Optuna...
# [I 2025-11-10 16:59:43,960] Trial 0 finished with value: 0.8929000711143472 and parameters: {'C': 0.07149659901488574}. Best is trial 0 with value: 0.8929000711143472.
# [I 2025-11-10 16:59:45,582] Trial 1 finished with value: 0.897650028621347 and parameters: {'C': 0.28446112963190556}. Best is trial 1 with value: 0.897650028621347.
# [I 2025-11-10 16:59:47,678] Trial 2 finished with value: 0.8957249861200033 and parameters: {'C': 0.6477197327714506}. Best is trial 1 with value: 0.897650028621347.
# [I 2025-11-10 16:59:55,275] Trial 3 finished with value: 0.8828500017285194 and parameters: {'C': 4.11999147957859}. Best is trial 1 with value: 0.897650028621347.
# [I 2025-11-10 16:59:59,215] Trial 4 finished with value: 0.8866500029832379 and parameters: {'C': 2.420848738161974}. Best is trial 1 with value: 0.897650028621347.
# [I 2025-11-10 17:00:00,402] Trial 5 finished with value: 0.8849500692294567 and parameters: {'C': 0.043869062061147296}. Best is trial 1 with value: 0.897650028621347.
# [I 2025-11-10 17:00:03,336] Trial 6 finished with value: 0.8919500079897378 and parameters: {'C': 1.1918613483814635}. Best is trial 1 with value: 0.897650028621347.
# [I 2025-11-10 17:00:05,017] Trial 7 finished with value: 0.8733500417156447 and parameters: {'C': 0.02346943185736879}. Best is trial 1 with value: 0.897650028621347.
# [I 2025-11-10 17:00:06,231] Trial 8 finished with value: 0.8628750442024887 and parameters: {'C': 0.015340960465633416}. Best is trial 1 with value: 0.897650028621347.
# [I 2025-11-10 17:00:07,412] Trial 9 finished with value: 0.8708500429624885 and parameters: {'C': 0.02060384270998195}. Best is trial 1 with value: 0.897650028621347.
# [I 2025-11-10 17:00:08,890] Trial 10 finished with value: 0.8977500292464563 and parameters: {'C': 0.19530866010092318}. Best is trial 10 with value: 0.8977500292464563.
# [I 2025-11-10 17:00:10,298] Trial 11 finished with value: 0.897325037370722 and parameters: {'C': 0.18502347984383694}. Best is trial 10 with value: 0.8977500292464563.
# [I 2025-11-10 17:00:11,796] Trial 12 finished with value: 0.8981750304969564 and parameters: {'C': 0.21703468783241053}. Best is trial 12 with value: 0.8981750304969564.
# [I 2025-11-10 17:00:13,190] Trial 13 finished with value: 0.8963500673687533 and parameters: {'C': 0.12299726223722998}. Best is trial 12 with value: 0.8981750304969564.
# [I 2025-11-10 17:00:15,094] Trial 14 finished with value: 0.8970000123709406 and parameters: {'C': 0.4904490670341297}. Best is trial 12 with value: 0.8981750304969564.
# [I 2025-11-10 17:00:16,944] Trial 15 finished with value: 0.8959250642433002 and parameters: {'C': 0.10776644888046549}. Best is trial 12 with value: 0.8981750304969564.
# [I 2025-11-10 17:00:19,638] Trial 16 finished with value: 0.8924000061153471 and parameters: {'C': 1.0971631499048087}. Best is trial 12 with value: 0.8981750304969564.
# [I 2025-11-10 17:00:28,564] Trial 17 finished with value: 0.8792499773496288 and parameters: {'C': 8.157318063924789}. Best is trial 12 with value: 0.8981750304969564.
# [I 2025-11-10 17:00:30,539] Trial 18 finished with value: 0.8976500117467688 and parameters: {'C': 0.370892816214184}. Best is trial 12 with value: 0.8981750304969564.
# [I 2025-11-10 17:00:31,769] Trial 19 finished with value: 0.8885000867334568 and parameters: {'C': 0.05575019500964667}. Best is trial 12 with value: 0.8981750304969564.
# [I 2025-11-10 17:00:33,320] Trial 20 finished with value: 0.8981250311218782 and parameters: {'C': 0.20568400696898087}. Best is trial 12 with value: 0.8981750304969564.
# [I 2025-11-10 17:00:34,773] Trial 21 finished with value: 0.8977500292464563 and parameters: {'C': 0.19498508370086967}. Best is trial 12 with value: 0.8981750304969564.
# [I 2025-11-10 17:00:36,988] Trial 22 finished with value: 0.8951249992439251 and parameters: {'C': 0.7295753551333262}. Best is trial 12 with value: 0.8981750304969564.
# [I 2025-11-10 17:00:38,516] Trial 23 finished with value: 0.8982500361219095 and parameters: {'C': 0.2231589182966078}. Best is trial 23 with value: 0.8982500361219095.
# [I 2025-11-10 17:00:39,950] Trial 24 finished with value: 0.8948500598670659 and parameters: {'C': 0.09572435492356168}. Best is trial 23 with value: 0.8982500361219095.
# [I 2025-11-10 17:00:41,445] Trial 25 finished with value: 0.8837750679780195 and parameters: {'C': 0.04114009981160798}. Best is trial 23 with value: 0.8982500361219095.
# [I 2025-11-10 17:00:43,331] Trial 26 finished with value: 0.8978000098720033 and parameters: {'C': 0.32085230003625503}. Best is trial 23 with value: 0.8982500361219095.
# [I 2025-11-10 17:00:46,387] Trial 27 finished with value: 0.8899500179869878 and parameters: {'C': 1.4926117481183034}. Best is trial 23 with value: 0.8982500361219095.
# [I 2025-11-10 17:00:47,763] Trial 28 finished with value: 0.8967500567445189 and parameters: {'C': 0.14443669800726203}. Best is trial 23 with value: 0.8982500361219095.
# [I 2025-11-10 17:00:49,068] Trial 29 finished with value: 0.8937750686155034 and parameters: {'C': 0.0778671985050933}. Best is trial 23 with value: 0.8982500361219095.
# Best params: {'C': 0.2231589182966078}
# Train acc: 0.9623, Test acc: 0.9008, Time: 69.88s

# %%
def nb_objective(trial, return_model=False, best_params=None):
    if best_params is None:
        alpha = trial.suggest_loguniform("alpha", 0.01, 2)
    else:
        alpha = best_params["alpha"]

    model = MultinomialNB(alpha=alpha)
    if return_model:
        model.fit(x_train_tfidf, y_train)
        return model
    score = cross_val_score(model, x_train_tfidf, y_train, cv=3, scoring="accuracy", n_jobs=-1).mean()
    return score

run_optuna("Multinomial NB", nb_objective, n_trials=30)
# Out:
# [I 2025-11-10 17:00:52,586] A new study created in memory with name: no-name-f4b875e8-f1b7-400f-8f63-79aed8ee6825
# Optimizing Multinomial NB with Optuna...
# [I 2025-11-10 17:00:53,176] Trial 0 finished with value: 0.8716499748401914 and parameters: {'alpha': 0.06210005963628852}. Best is trial 0 with value: 0.8716499748401914.
# [I 2025-11-10 17:00:53,754] Trial 1 finished with value: 0.8715499817148946 and parameters: {'alpha': 0.31272714368157606}. Best is trial 0 with value: 0.8716499748401914.
# [I 2025-11-10 17:00:54,324] Trial 2 finished with value: 0.8716749754652072 and parameters: {'alpha': 0.05785470298416864}. Best is trial 2 with value: 0.8716749754652072.
# [I 2025-11-10 17:00:54,781] Trial 3 finished with value: 0.8708499829639883 and parameters: {'alpha': 0.7145897430845739}. Best is trial 2 with value: 0.8716749754652072.
# [I 2025-11-10 17:00:55,185] Trial 4 finished with value: 0.8711999617149572 and parameters: {'alpha': 0.01133299535167289}. Best is trial 2 with value: 0.8716749754652072.
# [I 2025-11-10 17:00:55,591] Trial 5 finished with value: 0.871524966090254 and parameters: {'alpha': 0.02035587294010374}. Best is trial 2 with value: 0.8716749754652072.
# [I 2025-11-10 17:00:56,008] Trial 6 finished with value: 0.8714249767148633 and parameters: {'alpha': 0.3261026870746007}. Best is trial 2 with value: 0.8716749754652072.
# [I 2025-11-10 17:00:56,424] Trial 7 finished with value: 0.8717749798402227 and parameters: {'alpha': 0.07869832537888481}. Best is trial 7 with value: 0.8717749798402227.
# [I 2025-11-10 17:00:56,849] Trial 8 finished with value: 0.872049992340254 and parameters: {'alpha': 0.21166156841580613}. Best is trial 8 with value: 0.872049992340254.
# [I 2025-11-10 17:00:57,265] Trial 9 finished with value: 0.8715249848397852 and parameters: {'alpha': 0.1356031215122487}. Best is trial 8 with value: 0.872049992340254.
# [I 2025-11-10 17:00:57,682] Trial 10 finished with value: 0.8686749979608948 and parameters: {'alpha': 1.9992200224217098}. Best is trial 8 with value: 0.872049992340254.
# [I 2025-11-10 17:00:58,101] Trial 11 finished with value: 0.8717749798402227 and parameters: {'alpha': 0.0782061724223604}. Best is trial 8 with value: 0.872049992340254.
# [I 2025-11-10 17:00:58,514] Trial 12 finished with value: 0.871974988590254 and parameters: {'alpha': 0.25370361906923644}. Best is trial 8 with value: 0.872049992340254.
# [I 2025-11-10 17:00:58,941] Trial 13 finished with value: 0.8712249792145509 and parameters: {'alpha': 0.4130292107235225}. Best is trial 8 with value: 0.872049992340254.
# [I 2025-11-10 17:00:59,347] Trial 14 finished with value: 0.8706999885886603 and parameters: {'alpha': 0.9888275922630873}. Best is trial 8 with value: 0.872049992340254.
# [I 2025-11-10 17:00:59,759] Trial 15 finished with value: 0.8716749867149259 and parameters: {'alpha': 0.1486722120156226}. Best is trial 8 with value: 0.872049992340254.
# [I 2025-11-10 17:01:00,177] Trial 16 finished with value: 0.8719749942151133 and parameters: {'alpha': 0.18053789214854132}. Best is trial 8 with value: 0.872049992340254.
# [I 2025-11-10 17:01:00,588] Trial 17 finished with value: 0.8714249692150507 and parameters: {'alpha': 0.030335069609037}. Best is trial 8 with value: 0.872049992340254.
# [I 2025-11-10 17:01:01,006] Trial 18 finished with value: 0.8715499817148946 and parameters: {'alpha': 0.13006944770572182}. Best is trial 8 with value: 0.872049992340254.
# [I 2025-11-10 17:01:01,423] Trial 19 finished with value: 0.8710499692145821 and parameters: {'alpha': 0.6355790777882595}. Best is trial 8 with value: 0.872049992340254.
# [I 2025-11-10 17:01:01,838] Trial 20 finished with value: 0.8719499935900977 and parameters: {'alpha': 0.18824511833942797}. Best is trial 8 with value: 0.872049992340254.
# [I 2025-11-10 17:01:02,266] Trial 21 finished with value: 0.8720749910903165 and parameters: {'alpha': 0.21708311873745598}. Best is trial 21 with value: 0.8720749910903165.
# [I 2025-11-10 17:01:02,688] Trial 22 finished with value: 0.8709999717144572 and parameters: {'alpha': 0.5031053116915725}. Best is trial 21 with value: 0.8720749910903165.
# [I 2025-11-10 17:01:03,120] Trial 23 finished with value: 0.872049992340254 and parameters: {'alpha': 0.2128983832582215}. Best is trial 21 with value: 0.8720749910903165.
# [I 2025-11-10 17:01:03,528] Trial 24 finished with value: 0.8702249767133634 and parameters: {'alpha': 1.128865127519399}. Best is trial 21 with value: 0.8720749910903165.
# [I 2025-11-10 17:01:03,946] Trial 25 finished with value: 0.871749979215207 and parameters: {'alpha': 0.09204580019350747}. Best is trial 21 with value: 0.8720749910903165.
# [I 2025-11-10 17:01:04,363] Trial 26 finished with value: 0.872099989840379 and parameters: {'alpha': 0.24085125887286546}. Best is trial 26 with value: 0.872099989840379.
# [I 2025-11-10 17:01:04,751] Trial 27 finished with value: 0.8712749748397227 and parameters: {'alpha': 0.4013196725713167}. Best is trial 26 with value: 0.872099989840379.
# [I 2025-11-10 17:01:05,297] Trial 28 finished with value: 0.8713749698399726 and parameters: {'alpha': 0.04124303672957301}. Best is trial 26 with value: 0.872099989840379.
# [I 2025-11-10 17:01:05,881] Trial 29 finished with value: 0.8716749792151134 and parameters: {'alpha': 0.11267223021166439}. Best is trial 26 with value: 0.872099989840379.
# Best params: {'alpha': 0.24085125887286546}
# Train acc: 0.9003, Test acc: 0.8751, Time: 13.47s

# %%
def rf_objective(trial, return_model=False, best_params=None):
    if best_params is None:
        n_estimators = trial.suggest_int("n_estimators", 100, 1000)
        max_depth = trial.suggest_int("max_depth", 10, 70)
        min_samples_split = trial.suggest_int("min_samples_split", 2, 20)
        max_features = trial.suggest_categorical("max_features", ["sqrt", "log2"])
    else:
        n_estimators = best_params["n_estimators"]
        max_depth = best_params["max_depth"]
        min_samples_split = best_params["min_samples_split"]
        max_features = best_params["max_features"]

    model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        max_features=max_features,
        random_state=42,
        n_jobs=-1
    )
    if return_model:
        model.fit(x_train_tfidf, y_train)
        return model
    score = cross_val_score(model, x_train_tfidf, y_train, cv=3, scoring="accuracy", n_jobs=-1).mean()
    return score

run_optuna("Random Forest", rf_objective, n_trials=5)
# Out:
# [I 2025-11-10 17:01:06,069] A new study created in memory with name: no-name-ae5e6fc6-46c7-4494-bf2e-43813810f354
# Optimizing Random Forest with Optuna...
# [I 2025-11-10 17:02:51,498] Trial 0 finished with value: 0.8467249310601296 and parameters: {'n_estimators': 992, 'max_depth': 44, 'min_samples_split': 17, 'max_features': 'log2'}. Best is trial 0 with value: 0.8467249310601296.
# [I 2025-11-10 17:04:03,081] Trial 1 finished with value: 0.8427999398050048 and parameters: {'n_estimators': 949, 'max_depth': 31, 'min_samples_split': 18, 'max_features': 'log2'}. Best is trial 0 with value: 0.8467249310601296.
# [I 2025-11-10 17:05:06,436] Trial 2 finished with value: 0.8416249254288953 and parameters: {'n_estimators': 500, 'max_depth': 47, 'min_samples_split': 15, 'max_features': 'log2'}. Best is trial 0 with value: 0.8467249310601296.
# [I 2025-11-10 17:06:33,151] Trial 3 finished with value: 0.8462249954328954 and parameters: {'n_estimators': 507, 'max_depth': 68, 'min_samples_split': 15, 'max_features': 'log2'}. Best is trial 0 with value: 0.8467249310601296.
# [I 2025-11-10 17:07:20,054] Trial 4 finished with value: 0.8404749566766768 and parameters: {'n_estimators': 595, 'max_depth': 31, 'min_samples_split': 15, 'max_features': 'log2'}. Best is trial 0 with value: 0.8467249310601296.
# Best params: {'n_estimators': 992, 'max_depth': 44, 'min_samples_split': 17, 'max_features': 'log2'}
# Train acc: 0.9651, Test acc: 0.8475, Time: 445.32s

# %%
# Results with TF-IDF POSTAGS

df_results = pd.DataFrame(results).sort_values(by="Test Acc", ascending=False)
print("\nModel Comparison:\n")
df_results
# Out:
# Model Comparison:
#                  Model                                        Best Params  \
# 1           Linear SVM                          {'C': 0.2231589182966078}
# 0  Logistic Regression    {'C': 4.510838215623556, 'solver': 'liblinear'}
# 2       Multinomial NB                     {'alpha': 0.24085125887286546}
# 3        Random Forest  {'n_estimators': 992, 'max_depth': 44, 'min_sa...
#
#    Train Acc  Test Acc  Runtime (s)
# 1   0.962275    0.9008    69.876518
# 0   0.975300    0.8994   163.367326
# 2   0.900350    0.8751    13.469675
# 3   0.965125    0.8475   445.319406
